# %%
months = ['jan','feb','mar','apr','may','jun','jul','aug','sept','oct','nov','dec']
monthnum = int(input('enter month no(1-12)'))
if monthnum>=1 and

# %%
a = [a,b,c,d]
OR a.remove('a')
OR remove_item = a.pop(0)/del a[0]/del a [0:2]
OR a.clear[]
# Out:
#   Cell In[2], line 2
#     OR a.remove('a')
#        ^
# SyntaxError: invalid syntax

# %%
key = [101,102,103,104]
values = ['amit','rahul','priya','sneha']
student_dict = dict(zip(key, values))
print('dictionary:',student_dict)
# Out:
# dictionary: {101: 'amit', 102: 'rahul', 103: 'priya', 104: 'sneha'}

# %%
a = [1,2,3,3,4,5,5,6]
u = list(set(a))
print(u)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list1 = [10, 20, 30, 40, 50]
list2 = [30, 40, 50, 60, 70]
common = []
for element in list1:
    if element in list2:
        common.append(element)
